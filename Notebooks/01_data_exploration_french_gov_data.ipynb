# %% [markdown]
# Import the packages

# %%
import pandas as pd
import numpy as np

import xlrd
import openpyxl

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Import the datasets for 2001-2015:

# %%
df_2001 = pd.read_excel("../Data/France/Raw/2001.xls")
df_2002 = pd.read_excel("../Data/France/Raw/2002.xls")
df_2003 = pd.read_excel("../Data/France/Raw/2003.xls")
df_2004 = pd.read_excel("../Data/France/Raw/2004.xls")
df_2005 = pd.read_excel("../Data/France/Raw/2005.xls")
df_2006 = pd.read_excel("../Data/France/Raw/2006.xls")
df_2007 = pd.read_excel("../Data/France/Raw/2007.xls")
df_2008 = pd.read_excel("../Data/France/Raw/2008.xls")
df_2009 = pd.read_excel("../Data/France/Raw/2009.xls")
df_2010 = pd.read_excel("../Data/France/Raw/2010.xls")
df_2011 = pd.read_excel("../Data/France/Raw/2011.xls")
df_2012 = pd.read_csv("../Data/France/Raw/2012.csv", sep=";", encoding="latin-1")
df_2013 = pd.read_csv("../Data/France/Raw/2013.csv", sep=";", encoding="latin-1")
df_2014 = pd.read_csv("../Data/France/Raw/2014.csv", sep=";", encoding="latin-1")
df_2015 = pd.read_csv("../Data/France/Raw/2015.csv", sep=";", encoding="latin-1")

df_dictionary_of_variables = pd.read_excel("../Data/France/Raw/dictionary_of_variables.xlsx")

pd.set_option("display.max_columns", None)

# %% [markdown]
# Let's see the data for 2015:

# %%
print("Data: 2015:")
display(df_2015.head(2))
display(df_2015.info())
# Out:
# Data: 2015:
#   lib_mrq_doss lib_mod_doss     mrq_utac mod_utac                      dscom  \
# 0  ALFA ROMEO          159   ALFA ROMEO      159       159 1750 Tbi (200ch)
# 1  ALFA ROMEO          159   ALFA ROMEO      159   159 2.0 JTDm (170ch) ECO
#
#                cnit           tvv energ hybride  puiss_admin  puiss_max  \
# 0  M10ALFVP000G340   939AXN1B52C    ES     non            12      147.0
# 1  M10ALFVP000U221   939AXP1B54C    GO     non             9      125.0
#
#    puiss_heure typ_boite_nb_rapp  conso_urb_93  conso_exurb  conso_mixte  \
# 0          NaN              M 6           11.3          5.8          7.8
# 1          NaN              M 6            6.6          4.3          5.1
#
#    co2_mixte  co_typ_1     hc    nox  hcnox   ptcl  masse_ordma_min  \
# 0      182.0     0.647  0.052  0.032    NaN  0.002             1505
# 1      136.0     0.192    NaN  0.169   0.19  0.003             1565
#
#    masse_ordma_max                 champ_v9 date_maj
# ...

# %% [markdown]
# Let's see the data for 2014:

# %%
print("Data: 2014:")
display(df_2014.head(2))
display(df_2014.info())
# Out:
# Data: 2014:
#       lib_mrq lib_mod_doss lib_mod                 dscom             cnit  \
# 0  ALFA-ROMEO          159     159  159 1750 Tbi (200ch)  M10ALFVP000G340
# 1  ALFA-ROMEO          159     159  159 1750 Tbi (200ch)  M10ALFVP000H341
#
#            tvv cod_cbr hybride  puiss_admin_98 puiss_max typ_boite_nb_rapp  \
# 0  939AXN1B52C      ES     non              12       147               M 6
# 1  939BXN1B53C      ES     non              12       147               M 6
#
#      conso_urb  conso_exurb  conso_mixte    co2     co_typ_1           hc  \
# 0  11,30000019  5,800000191  7,800000191  182.0  0,647000015  0,052000001
# 1         11,5            6            8  186.0  0,647000015  0,052000001
#
#            nox hcnox   ptcl  masse_ordma_min  masse_ordma_max  \
# 0  0,032000002   NaN  0,002             1505             1505
# 1  0,032000002   NaN  0,002             1555             1555
#
#                  champ_v9 date_maj Carrosserie      gamme  Unnamed: 26  \
# ...

# %% [markdown]
# Let's see the data for 2013:

# %%
print("Data: 2013:")
display(df_2013.head(2))
display(df_2013.info())
# Out:
# Data: 2013:
#        Marque Modèle dossier Modèle UTAC   Désignation commerciale  \
# 0  ALFA-ROMEO            159         159      159 1750 Tbi (200ch)
# 1  ALFA-ROMEO            159         159  159 2.0 JTDm (170ch) ECO
#
#               CNIT Type Variante Version (TVV) Carburant Hybride  \
# 0  M10ALFVP000G340                 939AXN1B52C        ES     non
# 1  M10ALFVP000U221                 939AXP1B54C        GO     non
#
#    Puissance administrative  Puissance maximale (kW) Boîte de vitesse  \
# 0                        12                    147.0              M 6
# 1                         9                    125.0              M 6
#
#    Consommation urbaine (l/100km)  Consommation extra-urbaine (l/100km)  \
# 0                            11.3                                   5.8
# 1                             6.6                                   4.3
#
#    Consommation mixte (l/100km)  CO2 (g/km)  CO type I (g/km)  HC (g/km)  \
# ...

# %% [markdown]
# Let's see the data for 2012:

# %%
print("Data: 2012:")
display(df_2012.head(2))
display(df_2012.info())
# Out:
# Data: 2012:
#       lib_mrq lib_mod_doss    lib_mod                            dscom  \
# 0  ALFA-ROMEO    GIULIETTA  GIULIETTA  GIULIETTA 1.4 T-jet (120ch) S/S
# 1  ALFA-ROMEO         MITO       MITO     MITO 0.9 Twin Air (85ch) S/S
#
#               cnit          tvv typ_cbr hybride  puiss_admin_98  puiss_max  \
# 0  M10ALFVP0000324   940FXF1A05      ES     non               7         85
# 1  M10ALFVP0000360  955AXW1B17B      ES     non               4         62
#
#   typ_boite_nb_rapp conso_urb conso_exurb conso_mixte    co2 co_typ_1     hc  \
# 0               M 6       8,4         5,3         6,4  149.0    0,356   0,03
# 1               M 6       4,9         3,8         4,2   98.0    0,528  0,049
#
#      nox hcnox ptcl  masse_ordma_min  masse_ordma_max                champ_v9  \
# 0  0,026   NaN  NaN             1355             1355  715/2007*692/2008EURO5
# 1  0,037   NaN  NaN             1205             1205  715/2007*692/2008EURO5
#
#    date_maj Carrosserie       gamme
# ...

# %% [markdown]
# Let's see the data for 2011:

# %%
print("Data: 2011:")
display(df_2011.head(2))
display(df_2011.info())
# Out:
# Data: 2011:
#       lib_mrq lib_mod_doss   lib_mod               dscom             cnit  \
# 0  ALFA-ROMEO          147  ALFA 147  147 1.6 TS (105ch)  M10ALFVP000M091
# 1  ALFA-ROMEO          147  ALFA 147  147 1.6 TS (120ch)  M10ALFVP000P093
#
#            tvv typ_cbr  puiss_admin_98  puiss_max typ_boite_nb_rapp  \
# 0  937BXA1A05L      ES               7       77.0               M 5
# 1  937BXB1A06L      ES               8       88.0               M 5
#
#    conso_urb  conso_exurb  conso_mixte    co2             champ_v9   date_maj
# 0       11.3          6.4          8.2  196.0  70/220*2003/76EURO4  Mars 2011
# 1       11.2          6.4          8.2  194.0  70/220*2003/76EURO4  Mars 2011
# <class 'pandas.DataFrame'>
# RangeIndex: 37816 entries, 0 to 37815
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   lib_mrq            37816 non-null  str
#  1   lib_mod_doss       37816 non-null  str
# ...

# %% [markdown]
# Let's see the data for 2010:

# %%
print("Data: 2010:")
display(df_2010.head(2))
display(df_2010.info())
# Out:
# Data: 2010:
#   MARQUE                MODELE VERSION             CNIT  puissance fiscale  \
# 0  SMART   SMART FORTWO COUPE ELECTRIC  M10SMTVP000E039                  5
# 1  SMART  SMART FORTWO Cabrio ELECTRIC  M10SMTVP000F040                  5
#
#    puissance reelle   bv  urb  ex-urb  mixte  CO2 carburant ETIQUETTE ENERGIE  \
# 0               NaN  M 1  NaN     NaN    NaN  NaN        EL                 A
# 1               NaN  M 1  NaN     NaN    NaN  NaN        EL                 A
#
#   BONUS(-)/MALUS(+)  Unnamed: 13 Unnamed: 14
# 0             -5000          NaN         NaN
# 1             -5000          NaN         NaN
# <class 'pandas.DataFrame'>
# RangeIndex: 25319 entries, 0 to 25318
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MARQUE             25319 non-null  str
#  1   MODELE VERSION     25319 non-null  str
#  2   CNIT               25319 non-null  str
# ...

# %% [markdown]
# Let's see the data for 2009:

# %%
print("Data: 2009:")
display(df_2009.head(2))
display(df_2009.info())
# Out:
# Data: 2009:
#        MARQUE       MODELE VERSION          CNIT  puissance fiscale  \
# 0  ALFA-ROMEO  MiTo 1.4 MPI (78ch)  MAL1101P0804                  5
# 1  ALFA-ROMEO  MiTo 1.4 MPI (78ch)  MAL1101PZ803                  5
#
#    puissance reelle   bv  urb  ex-urb  mixte  CO2 carburant ETIQUETTE ENERGIE  \
# 0              58.0  M 6  7.7     4.8    5.9  138        ES                 C
# 1              58.0  M 6  7.7     4.8    5.9  138        ES                 C
#
#   BONUS(-)/MALUS(+)  Unnamed: 13 Unnamed: 14
# 0                 -          NaN         NaN
# 1                 -          NaN         NaN
# <class 'pandas.DataFrame'>
# RangeIndex: 19477 entries, 0 to 19476
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MARQUE             19477 non-null  str
#  1   MODELE VERSION     19477 non-null  str
#  2   CNIT               19477 non-null  str
# ...

# %% [markdown]
# Let's see the data for 2008:

# %%
print("Data: 2008:")
display(df_2008.head(2))
display(df_2008.info())
# Out:
# Data: 2008:
#      MARQUE      MODELE VERSION          CNIT  puissance fiscale  \
# 0  DAIHATSU       CUORE II BVM5  MJD1102JU185                4.0
# 1    TOYOTA  PRIUS (75ch) VVT-i  MJT9162TM872                4.0
#
#    puissance reelle   bv  urb  ex-urb  mixte    CO2 carburant  \
# 0              51.0  M 5  5.5     3.8    4.4  104.0        ES
# 1              57.0  V 0  5.0     4.2    4.3  104.0        ES
#
#   ETIQUETTE ENERGIE BONUS(-)/MALUS( )    TYPE 2
# 0                 B              -700  MJD1102J
# 1                 B             -2000  MJT9162T
# <class 'pandas.DataFrame'>
# RangeIndex: 15375 entries, 0 to 15374
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MARQUE             15375 non-null  str
#  1   MODELE VERSION     15375 non-null  str
#  2   CNIT               15375 non-null  str
#  3   puissance fiscale  15373 non-null  float64
# ...

# %% [markdown]
# Let's see the data for 2007:

# %%
print("Data: 2007:")
display(df_2007.head(2))
display(df_2007.info())
# Out:
# Data: 2007:
#        MARQUE          MODELE VERSION          CNIT  puissance fiscale  \
# 0  ALFA-ROMEO  147 3P 1.6L TS (105ch)  MAL1301JZ595                  7
# 1  ALFA-ROMEO  147 3P 1.6L TS (120ch)  MAL1401JB597                  8
#
#    puissance reelle   bv   urb  ex-urb  mixte  CO2 carburant ETIQUETTE ENERGIE
# 0              77.0  M 5  11.3     6.4    8.2  196        ES                 E
# 1              88.0  M 5  11.2     6.4    8.2  194        ES                 E
# <class 'pandas.DataFrame'>
# RangeIndex: 15114 entries, 0 to 15113
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MARQUE             15114 non-null  str
#  1   MODELE VERSION     15114 non-null  str
#  2   CNIT               15102 non-null  str
#  3   puissance fiscale  15114 non-null  int64
#  4   puissance reelle   15114 non-null  float64
#  5   bv                 15114 non-null  str
# ...

# %% [markdown]
# Let's see the data for 2006:

# %%
print("Data: 2006:")
display(df_2006.head(2))
display(df_2006.info())
# Out:
# Data: 2006:
#    ALFA-ROMEO  147 3P 1.6L TS (105ch)  MAL1301JZ595  937AXA1A00H  ES   7  \
# 0  ALFA-ROMEO  147 3P 1.6L TS (120ch)  MAL1401JB597  937AXB1A01H  ES   8
# 1  ALFA-ROMEO   147 3P 2.0L SELESPEED  MAL1601JX599  937AXC1102H  ES  10
#
#     77.0  M 5  11.3  6.4  8.2    196  Janvier 2006
# 0   88.0  M 5  11.2  6.4  8.2  194.0  Janvier 2006
# 1  110.0  M 5  12.1  7.0  8.9  211.0  Janvier 2006
# <class 'pandas.DataFrame'>
# RangeIndex: 8258 entries, 0 to 8257
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ALFA-ROMEO              8258 non-null   str
#  1   147 3P 1.6L TS (105ch)  8258 non-null   str
#  2   MAL1301JZ595            8258 non-null   str
#  3   937AXA1A00H             8258 non-null   str
#  4   ES                      8258 non-null   str
#  5   7                       8258 non-null   int64
#  6   77.0                    8258 non-null   float64
# ...

# %% [markdown]
# Let's see the data for 2005:

# %%
print("Data: 2005:")
display(df_2005.head(2))
display(df_2005.info())
# Out:
# Data: 2005:
#        MARQUE         MODELE VERSION          CNIT puissance fiscale  \
# 0  ALFA-ROMEO  147 3P 1.6 TS (105ch)  MAL1301JY594                 7
# 1  ALFA-ROMEO  147 3P 1.6 TS (120ch)  MAL1401JA596                 8
#
#    puissance reelle   bv   urb  ex-urb  mixte  CO2 ENERGIE  Unnamed: 11  \
# 0              77.0  M 5  11.1     6.3    8.1  192      ES          NaN
# 1              88.0  M 5  11.2     6.4    8.2  194      ES          NaN
#
#    Unnamed: 12  Unnamed: 13  Unnamed: 14  NaN  nan.1  nan.2
# 0          NaN          NaN          NaN  NaN    NaN    NaN
# 1          NaN          NaN          NaN  NaN    NaN    NaN
# <class 'pandas.DataFrame'>
# RangeIndex: 3865 entries, 0 to 3864
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MARQUE             3865 non-null   str
#  1   MODELE VERSION     3865 non-null   str
#  2   CNIT               3865 non-null   str
# ...

# %% [markdown]
# Let's see the data for 2004:

# %%
print("Data: 2004:")
display(df_2004.head(2))
display(df_2004.info())
# Out:
# Data: 2004:
#       Marques             Modèles, Versions          CNIT CARBURANT  \
# 0  VOLKSWAGEN  LUPO 3L TDI (61ch) TIPTRONIC  MVW70K1RU464        GO
# 1  VOLKSWAGEN  LUPO 3L TDI (61ch) TIPTRONIC  MVW70K1RX467        GO
#
#    Puiss Administrative  Puissance max   BV  Conso urb  Conso ex-urb  \
# 0                     3           45.0  A 5        3.6           2.7
# 1                     3           45.0  A 5        4.2           2.8
#
#    Conso mixte  CO2    Unnamed: 11
# 0          3.0   81  Décembre 2003
# 1          3.3   88  Décembre 2003
# <class 'pandas.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Marques               29 non-null     str
#  1   Modèles, Versions     29 non-null     str
#  2   CNIT                  29 non-null     str
#  3   CARBURANT             29 non-null     str
# ...

# %% [markdown]
# Let's see the data for 2003:

# %%
print("Data: 2003:")
display(df_2003.head(2))
display(df_2003.info())
# Out:
# Data: 2003:
#        MARQUE        MODELE VERSION          CNIT         MINE ENERGIE  \
# 0  ALFA-ROMEO  147 3P 1.6TS (105ch)  MAL1301JL265   937AXA1A00      ES
# 1  ALFA-ROMEO  147 3P 1.6TS (105ch)  MAL1301JE355  937AXA1A00C      ES
#
#    puissance fiscale  puissance reelle   bv   urb  ex-urb  mixte    CO2  \
# 0                  7              77.0  M 5  11.1     6.3    8.1  192.0
# 1                  7              77.0  M 5  11.1     6.3    8.1  192.0
#
#        IMMAT
# 0 2003-03-01
# 1 2003-03-01
# <class 'pandas.DataFrame'>
# RangeIndex: 5398 entries, 0 to 5397
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MARQUE             5398 non-null   str
#  1   MODELE VERSION     5398 non-null   str
#  2   CNIT               5398 non-null   str
#  3   MINE               5398 non-null   str
#  4   ENERGIE            5398 non-null   str
#  5   puissance fiscale  5398 non-null   int64
# ...

# %% [markdown]
# Let's see the data for 2002:

# %%
print("Data: 2002:")
display(df_2002.head(2))
display(df_2002.info())
# Out:
# Data: 2002:
#    GROUPE      MARQUE        MODELE VERSION          CNIT Unnamed: 4  \
# 0     NaN  ALFA-ROMEO  147 3P 1.6TS (105ch)  MAL1301JL265  1301JL265
# 1     NaN  ALFA-ROMEO  147 3P 1.6TS (105ch)  MAL1301JP330  1301JP330
#
#   Unnamed: 5         MINE ENERGIE  puissance fiscale  puissance reelle   bv  \
# 0   1301J265   937AXA1A00      ES                  7              77.0  M 5
# 1   1301J330  937AXA1A00B      ES                  7              77.0  M 5
#
#     urb  ex-urb  mixte    CO2  IMMAT  SEGMENT
# 0  11.1     6.3    8.1  192.0    NaN      NaN
# 1  11.3     6.4    8.2  196.0    NaN      NaN
# <class 'pandas.DataFrame'>
# RangeIndex: 5183 entries, 0 to 5182
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GROUPE             0 non-null      float64
#  1   MARQUE             5183 non-null   str
#  2   MODELE VERSION     5183 non-null   str
# ...

# %% [markdown]
# Let's see the data for 2001:

# %%
print("Data: 2001:")
display(df_2001.head(2))
display(df_2001.info())
# Out:
# Data: 2001:
#       MARQUES       MODELE    TYP. MINES                      CNIT CARB  CV  \
# 0  VOLKSWAGEN  LUPO 3L TDI  MVW70C1R4385  6ESCANYX01AGFD5850021N0H   GO   3
# 1  VOLKSWAGEN  LUPO 3L TDI  MVW70C1RX572  6ESCAYZX01AGFD5850021N0H   GO   3
#
#    PUISS.   BV  Urbain  Ex.Urb  Mixte  CO2
# 0    45.0  A 5     3.6     2.7    3.0   81
# 1    45.0  A 5     3.6     2.7    3.0   81
# <class 'pandas.DataFrame'>
# RangeIndex: 1370 entries, 0 to 1369
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MARQUES     1370 non-null   str
#  1   MODELE      1370 non-null   str
#  2   TYP. MINES  1370 non-null   str
#  3   CNIT        1370 non-null   str
#  4   CARB        1370 non-null   str
#  5   CV          1370 non-null   int64
#  6   PUISS.      1370 non-null   float64
#  7   BV          1370 non-null   str
#  8   Urbain      1370 non-null   float64
#  9   Ex.Urb      1370 non-null   float64
# ...

# %%
df = pd.DataFrame()
df["year"] = np.arange(2001, 2016)
df["data_size"] = [df_2001.shape[0], df_2002.shape[0], df_2003.shape[0], 
           df_2004.shape[0], df_2005.shape[0], df_2006.shape[0], 
           df_2007.shape[0], df_2008.shape[0], df_2009.shape[0], 
           df_2010.shape[0], df_2011.shape[0], df_2012.shape[0], 
           df_2013.shape[0], df_2014.shape[0], df_2015.shape[0]]
df["cols"] = [df_2001.shape[1], df_2002.shape[1], df_2003.shape[1],
          df_2004.shape[1], df_2005.shape[1], df_2006.shape[1],
          df_2007.shape[1], df_2008.shape[1], df_2009.shape[1],
          df_2010.shape[1], df_2011.shape[1], df_2012.shape[1],
          df_2013.shape[1], df_2014.shape[1], df_2015.shape[1]]

display(df)
# Out:
#     year  data_size  cols
# 0   2001       1370    12
# 1   2002       5183    17
# 2   2003       5398    13
# 3   2004         29    12
# 4   2005       3865    18
# 5   2006       8258    13
# 6   2007      15114    12
# 7   2008      15375    14
# 8   2009      19477    15
# 9   2010      25319    15
# 10  2011      37816    16
# 11  2012      40052    26
# 12  2013      44850    26
# 13  2014      55044    30
# 14  2015      20880    26

# %%
col_list_2001 = df_2001.columns.tolist()
col_list_2002 = df_2002.columns.tolist()
col_list_2003 = df_2003.columns.tolist()
col_list_2004 = df_2004.columns.tolist()
col_list_2005 = df_2005.columns.tolist()
col_list_2006 = df_2006.columns.tolist()
col_list_2007 = df_2007.columns.tolist()
col_list_2008 = df_2008.columns.tolist()
col_list_2009 = df_2009.columns.tolist()
col_list_2010 = df_2010.columns.tolist()
col_list_2011 = df_2011.columns.tolist()
col_list_2012 = df_2012.columns.tolist()
col_list_2013 = df_2013.columns.tolist()
col_list_2014 = df_2014.columns.tolist()
col_list_2015 = df_2015.columns.tolist()

fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(111)
ax.bar(range(2001, 2016), [len(col_list_2001), len(col_list_2002), len(col_list_2003), len(col_list_2004), 
                           len(col_list_2005), len(col_list_2006), len(col_list_2007), len(col_list_2008), 
                           len(col_list_2009), len(col_list_2010), len(col_list_2011), len(col_list_2012), 
                           len(col_list_2013), len(col_list_2014), len(col_list_2015)])
ax.set_xlabel("Year")
ax.set_ylabel("Number of Columns")
ax.set_title("Number of Columns per Year");

# %%
cols_by_year = {
    2001: col_list_2001,
    2002: col_list_2002,
    2003: col_list_2003,
    2004: col_list_2004,
    2005: col_list_2005,
    2006: col_list_2006,
    2007: col_list_2007,
    2008: col_list_2008,
    2009: col_list_2009,
    2010: col_list_2010,
    2011: col_list_2011,
    2012: col_list_2012,
    2013: col_list_2013,
    2014: col_list_2014,
    2015: col_list_2015,
}

cols_by_year_upper = {
    year: [str(c).upper() for c in cols]   # first str(), then upper()
    for year, cols in cols_by_year.items()
}

all_cols = []
for year, cols in cols_by_year_upper.items():
    all_cols.extend(cols)

freq = pd.Series(all_cols).value_counts().reset_index()
freq.columns = ["column_name", "count"]

freq.head(20)
# Out:
#           column_name  count
# 0                CNIT     14
# 1                 CO2     12
# 2                  BV      9
# 3               MIXTE      8
# 4              MARQUE      8
# 5      MODELE VERSION      7
# 6   PUISSANCE FISCALE      7
# 7    PUISSANCE REELLE      7
# 8                 URB      7
# 9              EX-URB      7
# 10          CARBURANT      6
# 11  ETIQUETTE ENERGIE      4
# 12       LIB_MOD_DOSS      4
# 13              DSCOM      4
# 14                TVV      4
# 15          PUISS_MAX      4
# 16  TYP_BOITE_NB_RAPP      4
# 17        CONSO_EXURB      4
# 18        CONSO_MIXTE      4
# 19           CHAMP_V9      4

# %%
top_n = 20
top_freq = freq.head(top_n)

plt.figure(figsize=(10, 6))
plt.barh(top_freq["column_name"], top_freq["count"])
plt.gca().invert_yaxis()  # biggest on top
plt.xlabel("Number of years the column name is present")
plt.ylabel("Column name")
plt.title("Most common columns (2001-2015)");

# %%
display(df_dictionary_of_variables)
# Out:
#           Column-name section type  length  \
# 0        lib_mrq_utac      varchar      12
# 1        lib_mod_doss      varchar      20
# 2             lib_mod      varchar      20
# 3               dscom      varchar      91
# 4                cnit      varchar      15
# 5                 tvv      varchar      36
# 6             cod_cbr      varchar       5
# 7             hybride      varchar       3
# 8      puiss_admin_98        varnb       2
# 9           puiss_max        varnb      11
# 10  typ_boite_nb_rapp      varchar       3
# 11          conso_urb        varnb      11
# 12        conso_exurb        varnb      11
# 13        conso_mixte        varnb      11
# 14                co2        varnb       3
# 15           co_typ_1        varnb      11
# 16                 hc        varnb      11
# 17                nox        varnb      11
# 18              hcnox        varnb      11
# 19               ptcl        varnb       5
# 20    masse_ordma_min        varnb       4
# ...
